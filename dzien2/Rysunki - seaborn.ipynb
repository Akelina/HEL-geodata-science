# %% [markdown]
# ## Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
midwest=pd.read_csv('midwest_filter.csv')

# %%
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian     ...      percprof  poppovertyknown  \
# 0             98       249     ...      4.355859            63628
# 1             19        48     ...      2.870315            10529
# 2             35        16     ...      4.488572            14235
# 3             46       150     ...      4.197800            30337
# 4             14         5     ...      3.367680             4815
#
#    percpovertyknown  percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# ...

# %%
midwest.columns
# Out:
# Index(['PID', 'county', 'state', 'area', 'poptotal', 'popdensity', 'popwhite',
#        'popblack', 'popamerindian', 'popasian', 'popother', 'percwhite',
#        'percblack', 'percamerindan', 'percasian', 'percother', 'popadults',
#        'perchsd', 'percollege', 'percprof', 'poppovertyknown',
#        'percpovertyknown', 'percbelowpoverty', 'percchildbelowpovert',
#        'percadultpoverty', 'percelderlypoverty', 'inmetro', 'category',
#        'dot_size'],
#       dtype='object')

# %%
midwest.shape
# Out:
# (332, 29)

# %% [markdown]
# ### Histogramy

# %%
plt.subplots(figsize=(5,5))
sns.distplot(midwest['popwhite']);

# %%
plt.subplots(figsize=(6,6))
sns.distplot(midwest['popwhite'],bins=15,kde=False,rug=True);

# %%
plt.subplots(figsize=(6,6))
sns.distplot(midwest['popwhite'],bins=15,hist=False,rug=True);

# %%
plt.subplots(figsize=(6,6))
sns.kdeplot(midwest['popwhite'], shade=True);

# %%
plt.subplots(figsize=(8,8))
sns.kdeplot(midwest['popamerindian'], shade=True);
sns.kdeplot(midwest['popasian'], shade=True);
sns.kdeplot(midwest['popblack'], shade=True);

# %% [markdown]
# ### Scatterplots

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='area',y='poptotal',data=midwest);
plt.xlabel('Powierzchnia')
plt.ylabel('Populacja');

# %%
plt.subplots(figsize=(8,8))
sns.scatterplot(x='area',y='poptotal',data=midwest,hue='category');
plt.xlabel('Powierzchnia')
plt.ylabel('Populacja');

# %%
plt.subplots(figsize=(8,8))
sns.scatterplot(x='area',y='poptotal',data=midwest,hue='popwhite',size='popwhite',sizes=(10,200));
plt.xlabel('Powierzchnia')
plt.ylabel('Populacja');

# %%
plt.subplots(figsize=(10,10))
sns.regplot(x='area',y='poptotal',data=midwest);

# %%
sns.jointplot(x='area',y='poptotal',data=midwest,height=7);

# %%
sns.jointplot(midwest.area,midwest.poptotal,kind="hex",color="r",height=10);

# %% [markdown]
# Tutorial
#
# [seaborn] (https://seaborn.pydata.org/index.html)

# %%
sns.jointplot(x='area',y='poptotal',data=midwest,kind="kde",height=10);

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# zapisanie
sns.plot=sns.pairplot(iris,hue='species');

# %%
sns.plot.savefig("output2.jpg")

# %%
sns.plot=sns.pairplot(iris,hue='species',vars=["sepal_length","sepal_width"],height=4);
