# %% [markdown]
# **KLASTERYZACJA**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Tworzenie danych

# %%
from sklearn.datasets import make_blobs

# %% [markdown]
# Tworzona struktura danych jest tuplą dwóch tablic (n_samples). Pierwsza jest wektorem zawierajacym n_features, a druga numery centrów.

# %%
# Create Data
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=103)

# %%
data[0]
# Out:
# array([[  7.61084821,   6.05121785],
#        [ -8.40599464,   8.62833379],
#        [ -1.89542029,   2.33963111],
#        [  2.04444691,   0.64035056],
#        [ -2.39994406,  -6.96299608],
#        [ -0.05032492,  -0.67586678],
#        [  1.50209195,  -1.63326464],
#        [  4.19851961,  -5.50413192],
#        [  3.44961308,  -3.53898232],
#        [ -0.15961273,  -3.46079774],
#        [ -6.82796246,   5.53161162],
#        [  6.15404348,   5.7556143 ],
#        [  2.15978779,   0.66002052],
#        [  0.10128465,  -7.86975658],
#        [ -8.63814478,   5.54773229],
#        [ -0.76090733,   0.40113433],
#        [ -3.49517349,  -5.97724596],
#        [ -2.14342011,  -6.43059679],
#        [ -1.96255103,  -1.76775123],
#        [ -3.01450451,  -6.57010323],
#        [ -0.4861462 ,  -7.21766474],
#        [ 10.04373794,   5.74243479],
#        [  3.99154486,   4.46154131],
#        [  3.78460943,   8.08948689],
#        [ -0.14347121,  -9.02272286],
#        [ -1.71053523,  -7.98666603],
#        [ -2.44309368,  -7.44972829],
#        [ -1.33516537,  -5.00249293],
#        [ -5.38159025,   5.58081445],
#        [ -6.02053242,   6.41107944],
#        [  1.12094306,  -1.0289393 ],
#        [ -1.38406937,  -0.19045546],
#        [ -7.19865225,   7.52061889],
#        [ -1.54135511,  -3.18984103],
#        [ -5.23679623,   9.14904411],
#        [  8.48334368,   6.96397441],
#        [  3.04915226,   1.05797123],
#        [ -6.72563943,   4.40962791],
#        [ -3.20741818,  -6.20564352],
#        [ -1.17106151,  -0.47878712],
#        [  7.28812955,   5.91264913],
#        [  3.54028927,   6.34329675],
#        [  3.73164949,  -3.58292469],
#        [ -9.43569117,   5.17696654],
#        [  0.46642224,  -3.76419489],
#        [  1.56000976,  -6.06298337],
#        [  6.85295169,   8.71151128],
#        [ -7.06231218,   5.14981086],
#        [  6.88248773,   7.98565409],
#        [  2.94868558,  -1.86208765],
#        [ -7.02917219,   7.45736612],
#        [ -6.66991844,   6.17528791],
#        [  1.84287412,  -3.39581699],
#        [  0.49938183,  -2.22851415],
#        [  3.79302527,   6.87396627],
#        [  9.24549787,   4.47387052],
#        [ -2.03690003, -10.29326885],
#        [ -9.17424053,   3.42114986],
#        [ -9.8714637 ,   6.49672167],
#        [  6.10647144,   7.13922062],
#        [ -0.89864346,  -0.57141394],
#        [ -0.43790957,  -0.38874677],
#        [  7.61416462,   9.04651071],
#        [  8.0322609 ,   4.74793594],
#        [ -7.82284684,   5.63042506],
#        [  0.13436457,   1.39550109],
#        [ -1.8914691 ,  -6.02656657],
#        [ -4.40341607,  -5.32844187],
#        [  6.68734287,   4.04706923],
#        [ -3.5872497 ,  -6.68792177],
#        [  4.14692314,   1.65789742],
#        [ -2.18377271,  -5.68071466],
#        [  2.3218479 ,  -1.2239552 ],
#        [  7.18233904,   6.21636213],
#        [ -2.47438596,  -5.63522867],
#        [ -9.99619287,   8.71006545],
#        [  7.72213023,   8.32238402],
#        [ -9.12127005,  11.33943167],
#        [  2.20025836,   0.44513228],
#        [  1.86121818,  -0.50561269],
#        [ -2.43909621,  -6.79031363],
#        [ -0.25202526,  -3.78625019],
#        [  0.95243325,  -9.68055134],
#        [  0.53885636,  -5.98897906],
#        [ -2.84187407,  -6.33386859],
#        [ -1.69995292,  -9.69323849],
#        [  6.55798847,   8.7231627 ],
#        [ -7.97572782,   7.52473586],
#        [  7.67040188,   7.48493048],
#        [ -3.90477596,  -1.68396851],
#        [ -6.82527116,   5.36014274],
#        [ -1.08098534,  -3.18675794],
#        [  1.20473854,  -2.9651334 ],
#        [  6.62762519,   7.43221036],
#        [  5.95965376,   8.70415859],
#        [  5.18690343,   6.91785164],
#        [ -5.0810459 ,  10.92736569],
#        [ -4.17543768,   3.38454832],
#        [  0.19191045,   1.22372926],
#        [ -5.97454915,   6.65170916],
#        [  6.19066681,   6.16536909],
#        [ -3.02047973,  -7.7807157 ],
#        [ -0.61874795,  -7.62666107],
#        [  6.66539185,   6.80998672],
#        [  6.51517997,   6.37857983],
#        [  4.89022558,   3.60711868],
#        [ -4.11087142,   7.14883055],
#        [ -3.60086734,   4.72366153],
#        [ -6.55878196,   6.40162524],
#        [ -5.7357803 ,   5.81552847],
#        [ -7.16874741,   4.84654985],
#        [ -2.20268925,  -7.64139797],
#        [  8.1441538 ,   2.61085597],
#        [  2.18305477,  -1.8003467 ],
#        [ -0.69999514,  -1.4201561 ],
#        [ 11.01737113,   8.94250089],
#        [  2.93381941,   0.59140202],
#        [ -0.8738157 ,  -1.19208651],
#        [  5.9367517 ,   8.83309729],
#        [  6.07629958,  10.90326541],
#        [  0.29862302,   1.08487246],
#        [ -3.13471057,   9.6192521 ],
#        [  1.50466787,  -7.72935884],
#        [  4.94244049,   8.75089581],
#        [  7.93801532,   5.34620362],
#        [  3.24001645,  -0.92903663],
#        [  7.11272834,   7.0004841 ],
#        [  6.5867141 ,   6.99063622],
#        [ -2.2991332 ,  -5.66974632],
#        [ -4.5992122 ,   8.45666256],
#        [ -5.24003323,   8.74749692],
#        [  6.62535927,   7.76996293],
#        [ -0.721075  ,  -1.16915195],
#        [  6.89960024,   7.97923692],
#        [ -7.15887354,   5.58969716],
#        [  1.05033784,  -3.0531644 ],
#        [-12.29941868,   5.71564462],
#        [ -3.62476101,   4.73556542],
#        [  3.58888153,  -0.04348544],
#        [  5.22028332,   5.88658049],
#        [ -7.93901689,   6.97158079],
#        [ -9.02219607,   7.40006801],
#        [ -9.13943097,   6.32441256],
#        [ -7.84906149,   7.44323816],
#        [ -8.09399138,   7.64683223],
#        [  4.24282019,   5.48675705],
#        [ -8.64647012,   9.91477588],
#        [  8.13919525,   5.44451218],
#        [ -8.10526437,   7.20882905],
#        [  5.66186116,   5.6221465 ],
#        [  5.18933411,   0.74927422],
#        [  6.68697767,   6.57157506],
#        [  1.58635401,   2.78205113],
#        [  0.79730709,  -0.052876  ],
#        [ -4.76540305,   6.46579035],
#        [  4.03730839,   5.83579854],
#        [  0.74738576,   0.2421061 ],
#        [ -0.91006968,  -3.42813286],
#        [ -0.28850585,  -1.64998594],
#        [ -8.58575887,   6.82058961],
#        [ -0.99141605,   5.53093755],
#        [  7.37542239,   7.05927802],
#        [ -8.27962348,   3.76934048],
#        [ -5.17722436,   5.84900281],
#        [ -3.06080576,  -6.1185447 ],
#        [  9.15423565,   7.72609008],
#        [  2.03860691,  -1.74759364],
#        [ -8.01474996,   7.97774048],
#        [  0.54004603,  -6.58563101],
#        [ -0.35136347,  -9.61191418],
#        [  2.25082983,   1.93337248],
#        [ -3.52127602,  -8.99315866],
#        [  2.73005414,  -0.80255726],
#        [ -1.52122147,  -4.65780586],
#        [ -0.69913821,  -6.40668773],
#        [ -1.21077555,  -4.65170672],
#        [ -0.28913678,  -7.0703679 ],
#        [ -6.89990744,   6.56618773],
#        [ -5.80783649,   4.72647836],
#        [  0.4038471 ,   0.30659717],
#        [ -3.06375139,  -9.83378222],
#        [  0.40433027,  -3.64483596],
#        [ -0.31838016,  -6.74025862],
#        [  1.57603311,  -0.10691541],
#        [  6.69753748,   7.44126579],
#        [ -2.31297405,   0.39284331],
#        [ -1.80926563,  -6.21493744],
#        [  8.12657381,   8.13700782],
#        [  2.51131418,   1.13697693],
#        [ -0.41083915,  -3.47584826],
#        [ -7.6858611 ,   2.75406271],
#        [  1.41142779,  -4.06059609],
#        [  5.78565642,   6.53077108],
#        [ -0.13326168,  -4.12317992],
#        [  6.39831764,   6.23433317],
#        [ -3.12179632,  -7.65323208],
#        [ -6.1229695 ,   5.09306623],
#        [  9.872326  ,   3.46818676],
#        [ -5.34072003,  -7.24659385],
#        [  2.06082833,   0.43312369]])

# %% [markdown]
# ### Wizualizacja

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow');

# %% [markdown]
# **Tworzenie klastrów**

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 6.71914409,  6.7135902 ],
#        [-1.73630175, -7.05195597],
#        [-6.90017383,  6.52896074],
#        [ 0.91910232, -1.08203655]])

# %%
kmeans.labels_
# Out:
# array([0, 2, 3, 3, 1, 3, 3, 3, 3, 3, 2, 0, 3, 1, 2, 3, 1, 1, 3, 1, 1, 0,
#        0, 0, 1, 1, 1, 1, 2, 2, 3, 3, 2, 3, 2, 0, 3, 2, 1, 3, 0, 0, 3, 2,
#        3, 1, 0, 2, 0, 3, 2, 2, 3, 3, 0, 0, 1, 2, 2, 0, 3, 3, 0, 0, 2, 3,
#        1, 1, 0, 1, 3, 1, 3, 0, 1, 2, 0, 2, 3, 3, 1, 3, 1, 1, 1, 1, 0, 2,
#        0, 3, 2, 3, 3, 0, 0, 0, 2, 2, 3, 2, 0, 1, 1, 0, 0, 0, 2, 2, 2, 2,
#        2, 1, 0, 3, 3, 0, 3, 3, 0, 0, 3, 2, 1, 0, 0, 3, 0, 0, 1, 2, 2, 0,
#        3, 0, 2, 3, 2, 2, 3, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 0, 3, 0, 3, 3,
#        2, 0, 3, 3, 3, 2, 2, 0, 2, 2, 1, 0, 3, 2, 1, 1, 3, 1, 3, 1, 1, 1,
#        1, 2, 2, 3, 1, 3, 1, 3, 0, 3, 1, 0, 3, 3, 2, 3, 0, 3, 0, 1, 2, 0,
#        1, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow');
