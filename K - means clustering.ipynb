# %% [markdown]
# **KLASTERYZACJA**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Tworzenie danych

# %%
from sklearn.datasets import make_blobs

# %% [markdown]
# Tworzona struktura danych jest tuplą dwóch tablic (n_samples). Pierwsza jest wektorem zawierajacym n_features, a druga numery centrów.

# %%
# Create Data
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=103)

# %% [markdown]
# ### Wizualizacja

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow');

# %% [markdown]
# **Tworzenie klastrów**

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.91910232, -1.08203655],
#        [-6.90017383,  6.52896074],
#        [ 6.71914409,  6.7135902 ],
#        [-1.73630175, -7.05195597]])

# %%
kmeans.labels_
# Out:
# array([2, 1, 0, 0, 3, 0, 0, 0, 0, 0, 1, 2, 0, 3, 1, 0, 3, 3, 0, 3, 3, 2,
#        2, 2, 3, 3, 3, 3, 1, 1, 0, 0, 1, 0, 1, 2, 0, 1, 3, 0, 2, 2, 0, 1,
#        0, 3, 2, 1, 2, 0, 1, 1, 0, 0, 2, 2, 3, 1, 1, 2, 0, 0, 2, 2, 1, 0,
#        3, 3, 2, 3, 0, 3, 0, 2, 3, 1, 2, 1, 0, 0, 3, 0, 3, 3, 3, 3, 2, 1,
#        2, 0, 1, 0, 0, 2, 2, 2, 1, 1, 0, 1, 2, 3, 3, 2, 2, 2, 1, 1, 1, 1,
#        1, 3, 2, 0, 0, 2, 0, 0, 2, 2, 0, 1, 3, 2, 2, 0, 2, 2, 3, 1, 1, 2,
#        0, 2, 1, 0, 1, 1, 0, 2, 1, 1, 1, 1, 1, 2, 1, 2, 1, 2, 0, 2, 0, 0,
#        1, 2, 0, 0, 0, 1, 1, 2, 1, 1, 3, 2, 0, 1, 3, 3, 0, 3, 0, 3, 3, 3,
#        3, 1, 1, 0, 3, 0, 3, 0, 2, 0, 3, 2, 0, 0, 1, 0, 2, 0, 2, 3, 1, 2,
#        3, 0])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow');
