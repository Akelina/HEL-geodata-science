# %% [markdown]
# **Matplotlib** jest pakietem (zestawem modułów Pythona) do tworzenia dwuwymiarowych wykresów o jakości publikacyjnej w różnych formatach i środowiskach interaktywnych (IPython, jupyter notebook).  Opis biblioteki jest zawarty na stronie https://matplotlib.org/
#
# Interfejsem dostępy tego pakietu jest **pyplot**. Pracę z pakietem zaczynamy praktycznie zawsze linią kodu:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#  Linia
# </p><br>
# Podstawowa instrukcja rysowania ma postać,
#
# **plot**(oś x,oś y)
#
# Rysunek powstaje w tle i aby go zobaczyć używamy instrukcji **show()**

# %%
from numpy import *
from random import *

yy=zeros((10),float)
xx=zeros((10),float)
for i in range(0,10):
    yy[i]=uniform(0,10)
    xx[i]=i

plt.plot(xx,yy);

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#  Legenda, tytuł, opis osi
# </p>

# %%
x=[1,2,3]
y=[3,7,4]

plt.plot(x,y)
plt.xlabel('Zmienne')
plt.ylabel('Nasza funkcja')
plt.title('Wykres\nPrzykład 1');

# %%
x=[1,2,3]
y=[3,7,4]

x1=[1,2,3]
y1=[10,11,8]

plt.plot(x,y,label='Pierwsza linia')
plt.plot(x1,y1,label='Druga linia')
plt.xlabel('Zmienne')
plt.ylabel('Nasza funkcja')
plt.title('Wykres\nPrzykład 1a')
plt.legend();

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#  Wykres słupkowy i histogram
# </p>

# %%
x=[2,4,6,8,10]
y=[6,7,8,2,4]

plt.bar(x,y,label='Bars1')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph')
plt.legend();

# %%
x=[2,4,6,8,10]
y=[6,7,8,2,4]

x2=[1,3,5,9,11]
y2=[7,8,2,4,2]

plt.bar(x,y,label='Bars1')
plt.bar(x2,y2,label='Bars2')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph')
plt.legend();

# %%
xxx=zeros((100),float)
for i in range(0,100):
    xxx[i]=gauss(10,2)
#xxx=np.random.randn(100)*2+10   #normal mean=10, sd=2
#ids=[x for x in range(len(xxx))] # 0,1,2.....
bins=12 # albo tak
#bins=[2,4,6,8,10,12,14,16] # albo tak
plt.hist(xxx,bins,color='r',histtype='bar',rwidth=0.9)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph');

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:purple; font-style:bold"><br>
#  Wykres punktowy  - scatterplot
# </p>

# %%
x=[1,2,3,4,5,6,7,8]
y=[5,2,4,2,1,4,5,2]

plt.scatter(x,y,label='skitscat',color='r',marker='o',s=50)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph')
plt.legend();

# %% [markdown]
# Matplotlib jest złożoną biblioteką
#
# 1. Biblioteka jest ogromna, ok. 70000 linii kodu
# 2. Zawiera szereg interfejsów (sposobów tworzenia rysunków).
#
# Koncepcja Matplotlib Object Hierarchy
#
# ![image.png](attachment:image.png)

# %%
# Hierarchy w akcji

fig, _ =plt.subplots()
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
one_tick = fig.axes[0].yaxis.get_major_ticks()[0]
type(one_tick)
# Out:
# matplotlib.axis.YTick

# %% [markdown]
# ### Anatomia rysunku
#
# ![image.png](attachment:image.png)

# %%
# podstawowy sposób działania

fig, ax = plt.subplots()

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))     # 3 random time series
yrs = 1950 + rng

fig, ax = plt.subplots(figsize=(10, 5))                # one figure, one axes
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1]);
#fig.tight_layout()   # clear whitespace padding

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(8, 4))

ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')

ax2.hist(data, bins=np.arange(data.min(), data.max()),label=('x', 'y'))
ax2.legend(loc=(0.65, 0.8))
ax2.set_title('Frequencies of $x$ and $y$')
ax2.yaxis.tick_right();

# %%
(fig.axes[0] is ax1, fig.axes[1] is ax2)
# Out:
# (True, True)

# %%
gridsize = (2, 2)
fig = plt.figure(figsize=(10, 9))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2)
ax2 = plt.subplot2grid(gridsize, (1, 0))
ax3 = plt.subplot2grid(gridsize, (1, 1))

ax1.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax1.set_title('Combined debt growth over time')
ax1.legend(loc='upper left')
ax1.set_ylabel('Total debt')
ax1.set_xlim(xmin=yrs[0], xmax=yrs[-1])

ax2.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax2.set_title('Scatter: $x$ versus $y$')
ax2.set_xlabel('$x$')
ax2.set_ylabel('$y$')

ax3.hist(data, bins=np.arange(data.min(), data.max()),label=('x', 'y'))
ax3.legend(loc=(0.65, 0.8))
ax3.set_title('Frequencies of $x$ and $y$')
ax3.yaxis.tick_right();
