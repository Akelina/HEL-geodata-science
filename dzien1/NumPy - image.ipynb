# %% [markdown]
# **Numpy - zdjęcia satelitarne**

# %%
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
from skimage import data
import imageio

# %%
sat=imageio.imread('BalticSea.2014083.terra.367.500m.tif')

# %%
print(sat.shape)
# Out:
# (2958, 2504, 3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(sat);

# %%
imageio.imwrite('BalticSea.2014083.terra.367.500m_1.tif',sat[:,:,0])

# %%
plt.figure(figsize=(10,10))
plt.imshow(sat[:,:,0],cmap='gray');

# %% [markdown]
# Zadanie - Pobierz wartości pikseli z pionowej linii dla x=1000, wykonaj histogram i przekrój.

# %%
pion=np.array(sat[1000,:,0])
pion
# Out:
# array([220, 217, 220, ...,  83, 118, 159], dtype=uint8)

# %%
type(pion)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(12,6))
plt.hist(pion);

# %%
plt.figure(figsize=(15,6))
plt.plot(range(0,len(pion)),pion,linewidth=1);

# %% [markdown]
# Zadanie
#
# 1. Dla kanału pierwszego wyznacz wartości progowe poniżej i powyżej której znajduje się 800000 pikseli

# %%
rr,cc=sat[:,:,0].shape
print(rr,cc)
# Out:
# 2958 2504

# %%
xx=sat[:,:,0].reshape(rr*cc)
print(xx)
# Out:
# [15 12 27 ... 30 45 35]

# %%
xx.sort()
xx
# Out:
# Array([  0,   0,   0, ..., 255, 255, 255], dtype=uint8)

# %%
print(len(xx))
print( xx[800000])
print(xx[len(xx)-800000])
# Out:
# 7406832
# 13
# 219
